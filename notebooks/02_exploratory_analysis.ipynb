# %% [markdown]
# # 02: Exploratory Data Analysis

# %%
import sys
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
sys.path.append(str(Path("../src")))
from src.visuals import plot_top_genres, plot_top_artists, plot_feature_distribution, plot_energy_valence_scatter

# %%
tracks_df = pd.read_csv("../data/processed/tracks.csv")
artists_df = pd.read_csv("../data/processed/artists.csv")

# %%
plot_top_genres(artists_df)
plt.show()

# %%
plot_energy_valence_scatter(tracks_df)
plt.show()
