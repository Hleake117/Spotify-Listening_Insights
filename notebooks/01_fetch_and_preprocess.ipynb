# %% [markdown]
# # 01: Fetch and Preprocess Spotify Data

# %%
import sys
from pathlib import Path
sys.path.append(str(Path("../src")))
from src.auth import authenticate, load_tokens
from src.fetch_data import fetch_all_data
from src.preprocess import preprocess_all_data

# %%
tokens = load_tokens()
if not tokens:
    authenticate(interactive=True)
else:
    print("✓ Tokens found")

# %%
data = fetch_all_data()

# %%
processed_data = preprocess_all_data()
