# %% [markdown]
# # 03: Mood Clustering

# %%
import sys
from pathlib import Path
# Add project root to path so we can import from src
# This notebook is in notebooks/ directory, so go up one level to project root
project_root = Path().absolute().parent
sys.path.insert(0, str(project_root))
from src.features import perform_clustering

# %%
clustered_df = perform_clustering(n_clusters=4)
